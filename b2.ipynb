# %%
import pandas as pd

# %%
air= pd.read_csv('AirQualityUCI.csv')
heart= pd.read_csv('heartdisease.csv')

# %%
air
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  Wind  \
# 0     10-03-2004  18:00:00     2.6         1360       150  11.9
# 1     10-03-2004  19:00:00     2.0         1292       112   9.4
# 2     10-03-2004  20:00:00     2.2         1402        88   9.0
# 3     10-03-2004  21:00:00     2.2         1376        80   9.2
# 4     10-03-2004  22:00:00     1.6         1272        51   6.5
# ...          ...       ...     ...          ...       ...   ...
# 9352  04-04-2005  10:00:00     3.1         1314      -200  13.5
# 9353  04-04-2005  11:00:00     2.4         1163      -200  11.4
# 9354  04-04-2005  12:00:00     2.4         1142      -200  12.4
# 9355  04-04-2005  13:00:00     2.1         1003      -200   9.5
# 9356  04-04-2005  14:00:00     2.2         1071      -200  11.9
#
#       PT08.S2(NMHC)  Solor.R  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  Ozone  \
# 0              1046      166          1056      113          1692   1268
# ...

# %%
heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope ca thal  num
# 0        3  0    6    0
# 1        2  3    3    2
# ...

# %%
#DATA CLEANING

air.dropna(inplace=True)#drop missing values 
air.drop_duplicates(inplace= True)
air
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  Wind  \
# 0     10-03-2004  18:00:00     2.6         1360       150  11.9
# 1     10-03-2004  19:00:00     2.0         1292       112   9.4
# 2     10-03-2004  20:00:00     2.2         1402        88   9.0
# 3     10-03-2004  21:00:00     2.2         1376        80   9.2
# 4     10-03-2004  22:00:00     1.6         1272        51   6.5
# ...          ...       ...     ...          ...       ...   ...
# 9352  04-04-2005  10:00:00     3.1         1314      -200  13.5
# 9353  04-04-2005  11:00:00     2.4         1163      -200  11.4
# 9354  04-04-2005  12:00:00     2.4         1142      -200  12.4
# 9355  04-04-2005  13:00:00     2.1         1003      -200   9.5
# 9356  04-04-2005  14:00:00     2.2         1071      -200  11.9
#
#       PT08.S2(NMHC)  Solor.R  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  Ozone  \
# 0              1046      166          1056      113          1692   1268
# ...

# %%
#DATA CLEANING

heart.dropna(inplace=True)#drop missing values 
heart.drop_duplicates(inplace= True)
heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope ca thal  num
# 0        3  0    6    0
# 1        2  3    3    2
# ...

# %%
air.isna().sum() #checking for null values
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# Wind             0
# PT08.S2(NMHC)    0
# Solor.R          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# Ozone            0
# Temp             0
# RH               0
# AH               0
# dtype: int64

# %%
heart.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
#integration of datasets

subset_air=air[['Ozone','Temp']]
subset_air
# Out:
#       Ozone  Temp
# 0      1268  13.6
# 1       972  13.3
# 2      1074  11.9
# 3      1203  11.0
# 4      1110  11.2
# ...     ...   ...
# 9352   1729  21.9
# 9353   1269  24.3
# 9354   1092  26.9
# 9355    770  28.3
# 9356    816  28.5
#
# [9357 rows x 2 columns]

# %%
subset_heart=heart[['age','chol']]
subset_heart
# Out:
#      age  chol
# 0     63   233
# 1     67   286
# 2     67   229
# 3     37   250
# 4     41   204
# ..   ...   ...
# 298   45   264
# 299   68   193
# 300   57   131
# 301   57   236
# 302   38   175
#
# [303 rows x 2 columns]

# %%
merge_kiya = pd.merge(subset_air,subset_heart,left_on='Ozone',right_on='chol')
merge_kiya
# Out:
#      Ozone  Temp  age  chol
# 0      394   6.3   62   394
# 1      394  16.9   62   394
# 2      394  21.0   62   394
# 3      394  14.4   62   394
# 4      394  12.3   62   394
# ..     ...   ...  ...   ...
# 121    232  -0.6   54   232
# 122    232  -0.6   57   232
# 123    313  -0.6   64   313
# 124    313   5.8   64   313
# 125    262   5.2   55   262
#
# [126 rows x 4 columns]

# %%
#splitting data


from sklearn.model_selection import train_test_split
x = merge_kiya[['Ozone','Temp','chol']]
y = merge_kiya.age
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((100, 3), (26, 3), (100,), (26,))

# %%
#data transformation
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)
x_train,x_test
# Out:
# (     Ozone  Temp  chol
#  116    227   0.1   227
#  13     274  13.9   274
#  33     564   4.5   564
#  75     318   5.6   318
#  26     360  17.4   360
#  ..     ...   ...   ...
#  67     261   3.8   261
#  64     268   0.2   268
#  117    221  -0.1   221
#  47     308  15.7   308
#  44     407  16.2   407
#
#  [100 rows x 3 columns],
#       Ozone  Temp  chol
#  8      417  40.2   417
#  50     308   2.5   308
#  43     354   2.8   354
#  24     263  13.5   263
#  63     268   0.2   268
#  99     266   3.3   266
#  54     342   6.8   342
#  91     288   4.5   288
#  7      417  19.4   417
#  112    257   2.8   257
#  10     341  10.7   341
#  71     353  10.6   353
#  98     283   3.0   283
#  48     308  15.7   308
#  86     288   4.3   288
#  2      394  21.0   394
#  100    266   3.3   266
#  84     295   4.5   295
#  22     263  13.5   263
#  45     407   6.1   407
#  56     330   9.9   330
#  92     289   3.3   289
#  94     289   5.3   289
#  61     268  10.0   268
# ...

# %%
#error correction
merge_kiya
# Out:
#      Ozone  Temp  age  chol
# 0      394   6.3   62   394
# 1      394  16.9   62   394
# 2      394  21.0   62   394
# 3      394  14.4   62   394
# 4      394  12.3   62   394
# ..     ...   ...  ...   ...
# 121    232  -0.6   54   232
# 122    232  -0.6   57   232
# 123    313  -0.6   64   313
# 124    313   5.8   64   313
# 125    262   5.2   55   262
#
# [126 rows x 4 columns]

# %%
def remove_outliers(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    threshold = 1.5 * IQR
    outlier_mask = (column < Q1 - threshold) | (column > Q3 + threshold)
    return column[~outlier_mask]

# %%
# Remove outliers for each column using a loop
col_name = ['Temp','Ozone','age','chol']
for col in col_name:
    merge_kiya[col] = remove_outliers(merge_kiya[col])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))  # Adjust the figure size if needed

for col in col_name:
    sns.boxplot(data=merge_kiya[col])
    plt.title(col)
    plt.show()

# %%
merge_kiya
# Out:
#      Ozone  Temp   age   chol
# 0    394.0   6.3  62.0  394.0
# 1    394.0  16.9  62.0  394.0
# 2    394.0  21.0  62.0  394.0
# 3    394.0  14.4  62.0  394.0
# 4    394.0  12.3  62.0  394.0
# ..     ...   ...   ...    ...
# 121  232.0  -0.6  54.0  232.0
# 122  232.0  -0.6  57.0  232.0
# 123  313.0  -0.6  64.0  313.0
# 124  313.0   5.8  64.0  313.0
# 125  262.0   5.2  55.0  262.0
#
# [126 rows x 4 columns]

# %%
#cleaning
merge_kiya.dropna()
# Out:
#      Ozone  Temp   age   chol
# 0    394.0   6.3  62.0  394.0
# 1    394.0  16.9  62.0  394.0
# 2    394.0  21.0  62.0  394.0
# 3    394.0  14.4  62.0  394.0
# 4    394.0  12.3  62.0  394.0
# ..     ...   ...   ...    ...
# 121  232.0  -0.6  54.0  232.0
# 122  232.0  -0.6  57.0  232.0
# 123  313.0  -0.6  64.0  313.0
# 124  313.0   5.8  64.0  313.0
# 125  262.0   5.2  55.0  262.0
#
# [116 rows x 4 columns]

# %%
#DATA MODEL BUYILDING

#linear regression 

from sklearn.linear_model import LinearRegression

# Separate features and target
X = heart[['age']]
Y = heart['chol']

# Create and fit the linear regression model
model = LinearRegression()
model.fit(X, Y)

# Print the model coefficients and intercept
print(f"Coefficients: {model.coef_}")
print(f"Intercept: {model.intercept_}")

# Make predictions on the test data
Y_pred = model.predict(X)

# Evaluate the model performance
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y, Y_pred)
print(f"Mean squared error: {mse}")
# Out:
# Coefficients: [1.19694711]
# Intercept: 181.5325326881229
# Mean squared error: 2555.341342183493

# %%
age = 54
predicted_chol = model.predict([[age]])[0]
print(f"Predicted chol level for a person with age = 54: {predicted_chol}")
# Out:
# Predicted chol level for a person with age = 54: 246.167676680662
# E:\anaconda\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
age_value = 54
filtered_rows = heart[heart['age'] == age_value]
print(filtered_rows)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 17    54    1   4       140   239    0        0      160      0      1.2
# 55    54    1   4       124   266    0        2      109      1      2.2
# 58    54    1   3       125   273    0        2      152      0      0.5
# 63    54    0   3       135   304    1        0      170      0      0.0
# 64    54    1   4       120   188    0        0      113      0      1.4
# 67    54    1   3       150   232    0        2      165      0      1.6
# 105   54    1   2       108   309    0        0      156      0      0.0
# 127   54    1   4       110   239    0        0      126      1      2.8
# 130   54    1   3       120   258    0        2      147      0      0.4
# 162   54    0   3       110   214    0        0      158      0      1.6
# 167   54    0   2       132   288    1        2      159      1      0.0
# 188   54    1   2       192   283    0        2      195      0      0.0
# ...
